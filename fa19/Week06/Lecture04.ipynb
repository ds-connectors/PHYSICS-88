# %% [markdown]
# <a id='exercises'></a>

# %% [markdown]
# ## Interactive 3D Plots

# %%
col1,col2,col3 = np.loadtxt('PossiblyDifferentHousingData_3columns.txt', unpack = True)
len(col3)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-8-70aaa07a7435> in <module>
# ----> 1 col1,col2,col3 = np.loadtxt('PossiblyDifferentHousingData_3columns.txt', unpack = True)
#       2 len(col3)
#
# /srv/app/venv/lib/python3.6/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#     953             fname = os_fspath(fname)
#     954         if _is_string_like(fname):
# --> 955             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     956             fencoding = getattr(fh, 'encoding', 'latin1')
#     957             fh = iter(fh)
#
# /srv/app/venv/lib/python3.6/site-packages/numpy/lib/_datasource.py in open(path, mode, destpath, encoding, newline)
#     264
#     265     ds = DataSource(destpath)
# ...

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib notebook
#set the plots to display interactively (useful for 3d plotting,
#you can rotate the view by dragging)

fig = plt.figure(figsize=(4,4))
ax = Axes3D(fig)
ax.scatter(col1,col2,col3, c='r', marker='o')
ax.set_xlabel('Bus')
ax.set_ylabel('Grocery')
ax.set_zlabel('Rent')
# Out:
# <img src="data:image/png;base64,..." width="288">
# Text(0.5, 0, 'Rent')
